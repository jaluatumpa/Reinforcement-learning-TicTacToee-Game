# %%
# Reference url: https://github.com/MJeremy2017/reinforcement-learning-implementation/blob/master/TicTacToe/ticTacToe.py

# %% [markdown]
# ## play2,player1 as human and play random selection,player2 as computer

# %%
import numpy as np
import pickle
import pandas as pd
import matplotlib.pyplot as plt

BOARD_ROWS = 3
BOARD_COLS = 3

# %%
class State:
    def __init__(self, p1, p2):
        self.board = np.zeros((BOARD_ROWS, BOARD_COLS))
        self.p1 = p1
        self.p2 = p2
        self.isEnd = False
        self.boardHash = None
        # init p1 plays first
        self.playerSymbol = 1

    # get unique hash of current board state
    def getHash(self):
        self.boardHash = str(self.board.reshape(BOARD_COLS * BOARD_ROWS))
        return self.boardHash

    def winner(self):
        # row
        for i in range(BOARD_ROWS):
            if sum(self.board[i, :]) == 3:
                self.isEnd = True
                return 1
            if sum(self.board[i, :]) == -3:
                self.isEnd = True
                return -1
        # col
        for i in range(BOARD_COLS):
            if sum(self.board[:, i]) == 3:
                self.isEnd = True
                return 1
            if sum(self.board[:, i]) == -3:
                self.isEnd = True
                return -1
        # diagonal
        diag_sum1 = sum([self.board[i, i] for i in range(BOARD_COLS)])
        diag_sum2 = sum([self.board[i, BOARD_COLS - i - 1] for i in range(BOARD_COLS)])
        diag_sum = max(abs(diag_sum1), abs(diag_sum2))
        if diag_sum == 3:
            self.isEnd = True
            if diag_sum1 == 3 or diag_sum2 == 3:
                return 1
            else:
                return -1

        # tie
        # no available positions
        if len(self.availablePositions()) == 0:
            self.isEnd = True
            return 0
        # not end
        self.isEnd = False
        return None

    def availablePositions(self):
        positions = []
        for i in range(BOARD_ROWS):
            for j in range(BOARD_COLS):
                if self.board[i, j] == 0:
                    positions.append((i, j))  # need to be tuple
        return positions

    def updateState(self, position):
        self.board[position] = self.playerSymbol
        # switch to another player
        self.playerSymbol = -1 if self.playerSymbol == 1 else 1

    # only when game ends
    def giveReward(self):
        result = self.winner()
        # backpropagate reward
        if result == 1:
            self.p1.feedReward(1)
            self.p2.feedReward(0)
        elif result == -1:
            self.p1.feedReward(0)
            self.p2.feedReward(1)
        else:
            self.p1.feedReward(0.1)
            self.p2.feedReward(0.5)

    # board reset
    def reset(self):
        self.board = np.zeros((BOARD_ROWS, BOARD_COLS))
        self.boardHash = None
        self.isEnd = False
        self.playerSymbol = 1
     #play player1 and player2
    def play(self, rounds=100):
        winlist = []
        for i in range(rounds):
            if i % 10000 == 0:
                print("Rounds {}".format(i))
            if i % 100 == 0:
                self.p1.setEps(rounds, i)
                self.p2.setEps(rounds, i)
            while not self.isEnd:
                # Player 1
                positions = self.availablePositions()
                p1_action = self.p1.chooseAction(positions, self.board, self.playerSymbol)
                # take action and upate board state
                self.updateState(p1_action)
                board_hash = self.getHash()
                self.p1.addState(board_hash)
                # check board status if it is end

                win = self.winner()
                if win is not None:
                    # self.showBoard()
                    # ended with p1 either win or draw
                    self.giveReward()
                    self.p1.reset()
                    self.p2.reset()
                    self.reset()
                    break

                else:
                    # Player 2
                    positions = self.availablePositions()
                    p2_action = self.p2.chooseAction(positions, self.board, self.playerSymbol)
                    self.updateState(p2_action)
                    board_hash = self.getHash()
                    self.p2.addState(board_hash)

                    win = self.winner()
                    if win is not None:
                        # self.showBoard()
                        #ended with p2 either win or draw
                        self.giveReward()
                        self.p1.reset()
                        self.p2.reset()
                        self.reset()
                        break
            winlist.append(win)
        return (winlist)
    # play with computer
    def play2(self):
        while not self.isEnd:
            positions = self.availablePositions()
            p1_action = self.p1.chooseAction(positions)
            self.updateState(p1_action)
            win = self.winner()
            if win is not None:
                if win == 1:
                    self.reset()
                    return 1
                        
                else:
                    self.reset()
                    return 0
                       

            positions = self.availablePositions()
            p2_action = self.p2.chooseAction(positions, self.board, self.playerSymbol)
            self.updateState(p2_action)
            win = self.winner()
            if win is not None:
                if win == -1:
                    self.reset()
                    return -1
                        
                else:
                    self.reset()
                    return 0
                    
        return 0

    
    def showBoard(self):
        # p1: x  p2: o
        for i in range(0, BOARD_ROWS):
            print('-------------')
            out = '| '
            for j in range(0, BOARD_COLS):
                if self.board[i, j] == 1:
                    token = 'o'
                if self.board[i, j] == -1:
                    token = 'x'
                if self.board[i, j] == 0:
                    token = ' '
                out += token + ' | '
            print(out)
        print('-------------')

# %%
class Player:
    def __init__(self, name, eps_decay=False, start_exp_rate=0.3, end_exp_rate=0.05):
        self.name = name
        self.states = []  # record all positions taken
        self.lr = 0.2
        self.exp_rate = start_exp_rate
        
        self.decay_gamma = 0.9
        self.states_value = {}  # state -> value

        self.eps_decay = eps_decay
        self.start_exp_rate = start_exp_rate
        self.end_exp_rate = end_exp_rate
        
    def getHash(self, board):
        boardHash = str(board.reshape(BOARD_COLS * BOARD_ROWS))
        return boardHash
    
    def setEps(self, total_games, current_game):
        if (self.eps_decay == False):
            return
        else:
            self.exp_rate = self.start_exp_rate * (1. - current_game/total_games) + self.end_exp_rate * (current_game/total_games)
            if (np.mod(current_game, 1000) == 0):
                print ('decay rate modified at {} with current value of {}'.format(str(current_game), str(self.exp_rate)))
        return 

    def chooseAction(self, positions, current_board, symbol):
        if np.random.uniform(0, 1) <= self.exp_rate:
            # take random action
            idx = np.random.choice(len(positions))
            action = positions[idx]
        else:
            value_max = -999
            for p in positions:
                next_board = current_board.copy()
                next_board[p] = symbol
                next_boardHash = self.getHash(next_board)
                value = 0 if self.states_value.get(next_boardHash) is None else self.states_value.get(next_boardHash)
                # print("value", value)
                if value >= value_max:
                    value_max = value
                    action = p
        # print("{} takes action {}".format(self.name, action))
        return action

    # append a hash state
    def addState(self, state):
        self.states.append(state)

    # at the end of game, backpropagate and update states value
    def feedReward(self, reward):
        for st in reversed(self.states):
            if self.states_value.get(st) is None:
                self.states_value[st] = 0
            self.states_value[st] += self.lr * (self.decay_gamma * reward - self.states_value[st])
            reward = self.states_value[st]

    def reset(self):
        self.states = []

    def savePolicy(self):
        fw = open('policy_' + str(self.name), 'wb')
        pickle.dump(self.states_value, fw)
        fw.close()

    def loadPolicy(self, file):
        fr = open(file, 'rb')
        self.states_value = pickle.load(fr)
        fr.close()

# %%
import random
class HumanPlayer:
    def __init__(self, name):
        self.name = name
    def chooseAction(self, positions):
        return random.choice(positions) #random selection
    def addState(self, state):
        pass

    def feedReward(self, reward):
        pass

    def reset(self):
        pass

# %%
def trainonce(p1, p2, games = 5000):
    width=1000 # for slicing data to plot
    
    st = State(p1, p2)
    print("training...")
    wl = st.play(games)

    p1.savePolicy()
    p2.savePolicy()
    
    # Analysis
    analysis = []
    nsteps = int(games/width)
    for i in range(nsteps):
        start = width*i
        end = width*(i+1) - 1
        #print (start, end)
        temp = wl[start:end]
        analysis.append([i, start, end, temp.count(1), temp.count(-1), temp.count(0)])

    andf = pd.DataFrame(analysis)
    andf.columns = ['batch', 'start', 'end', 'p1win', 'p2win', 'tie']
    andf['p1win'] = andf['p1win'].apply(lambda x: x/width)
    andf['p2win'] = andf['p2win'].apply(lambda x: x/width)
    andf['tie'] = andf['tie'].apply(lambda x: x/width)
    
    #title_string = 'Exploration rate is ' + str(eps)
    #print (title_string)
    # Plot 
    plt.plot(andf['batch'], andf['p1win'])
    plt.plot(andf['batch'], andf['p2win'])
    plt.plot(andf['batch'], andf['tie'])
    plt.legend(['p1 win', 'p2 win', 'tie'])
    #plt.title(title_string)
    plt.show()
    
    return

# %%
# set some parameters
start_exp_rate=0.3
end_exp_rate=0.05
games = 50000

# %%
# Expt 1: Both P1 and P2 follow constant epsilon
# define P1 and P2 and then train 
p1 = Player("p1", eps_decay = False, start_exp_rate=start_exp_rate)
p2 = Player("p2", eps_decay = False, start_exp_rate=start_exp_rate)
trainonce(p1, p2, games=games)
# Out:
# training...
# Rounds 0
# Rounds 10000
# Rounds 20000
# Rounds 30000
# Rounds 40000

# %%
# Expt 2: P1 follows decaying epsilon and P2 follow constant epsilon
# define P1 and P2 and then train 
p1 = Player("p1", eps_decay = True, start_exp_rate=start_exp_rate, end_exp_rate=end_exp_rate)
p2 = Player("p2", eps_decay = False, start_exp_rate=start_exp_rate)
trainonce(p1, p2, games=games)
# Out:
# training...
# Rounds 0
# decay rate modified at 0 with current value of 0.3
# decay rate modified at 1000 with current value of 0.295
# decay rate modified at 2000 with current value of 0.29
# decay rate modified at 3000 with current value of 0.285
# decay rate modified at 4000 with current value of 0.28
# decay rate modified at 5000 with current value of 0.275
# decay rate modified at 6000 with current value of 0.27
# decay rate modified at 7000 with current value of 0.265
# decay rate modified at 8000 with current value of 0.26
# decay rate modified at 9000 with current value of 0.255
# Rounds 10000
# decay rate modified at 10000 with current value of 0.25
# decay rate modified at 11000 with current value of 0.245
# decay rate modified at 12000 with current value of 0.24
# decay rate modified at 13000 with current value of 0.23500000000000001
# decay rate modified at 14000 with current value of 0.23
# decay rate modified at 15000 with current value of 0.22499999999999998
# decay rate modified at 16000 with current value of 0.21999999999999997
# decay rate modified at 17000 with current value of 0.21499999999999997
# decay rate modified at 18000 with current value of 0.21
# decay rate modified at 19000 with current value of 0.20500000000000002
# Rounds 20000
# decay rate modified at 20000 with current value of 0.2
# decay rate modified at 21000 with current value of 0.195
# decay rate modified at 22000 with current value of 0.19
# decay rate modified at 23000 with current value of 0.185
# decay rate modified at 24000 with current value of 0.18
# decay rate modified at 25000 with current value of 0.175
# decay rate modified at 26000 with current value of 0.16999999999999998
# decay rate modified at 27000 with current value of 0.16499999999999998
# decay rate modified at 28000 with current value of 0.15999999999999998
# decay rate modified at 29000 with current value of 0.155
# Rounds 30000
# decay rate modified at 30000 with current value of 0.15
# decay rate modified at 31000 with current value of 0.145
# decay rate modified at 32000 with current value of 0.14
# decay rate modified at 33000 with current value of 0.135
# decay rate modified at 34000 with current value of 0.13
# decay rate modified at 35000 with current value of 0.125
# decay rate modified at 36000 with current value of 0.12
# decay rate modified at 37000 with current value of 0.11499999999999999
# decay rate modified at 38000 with current value of 0.11
# decay rate modified at 39000 with current value of 0.105
# Rounds 40000
# decay rate modified at 40000 with current value of 0.09999999999999999
# decay rate modified at 41000 with current value of 0.09500000000000001
# decay rate modified at 42000 with current value of 0.09000000000000001
# decay rate modified at 43000 with current value of 0.085
# decay rate modified at 44000 with current value of 0.08
# decay rate modified at 45000 with current value of 0.075
# decay rate modified at 46000 with current value of 0.06999999999999999
# decay rate modified at 47000 with current value of 0.06500000000000002
# decay rate modified at 48000 with current value of 0.06000000000000001
# decay rate modified at 49000 with current value of 0.05500000000000001

# %%
# Expt 3: both P1 and P2 follow decaying epsilon
# define P1 and P2 and then train 
p1 = Player("p1", eps_decay = True, start_exp_rate=start_exp_rate, end_exp_rate=end_exp_rate)
p2 = Player("p2", eps_decay = True, start_exp_rate=start_exp_rate, end_exp_rate=end_exp_rate)
trainonce(p1, p2, games=games)
# Out:
# training...
# Rounds 0
# decay rate modified at 0 with current value of 0.3
# decay rate modified at 0 with current value of 0.3
# decay rate modified at 1000 with current value of 0.295
# decay rate modified at 1000 with current value of 0.295
# decay rate modified at 2000 with current value of 0.29
# decay rate modified at 2000 with current value of 0.29
# decay rate modified at 3000 with current value of 0.285
# decay rate modified at 3000 with current value of 0.285
# decay rate modified at 4000 with current value of 0.28
# decay rate modified at 4000 with current value of 0.28
# decay rate modified at 5000 with current value of 0.275
# decay rate modified at 5000 with current value of 0.275
# decay rate modified at 6000 with current value of 0.27
# decay rate modified at 6000 with current value of 0.27
# decay rate modified at 7000 with current value of 0.265
# decay rate modified at 7000 with current value of 0.265
# decay rate modified at 8000 with current value of 0.26
# decay rate modified at 8000 with current value of 0.26
# decay rate modified at 9000 with current value of 0.255
# decay rate modified at 9000 with current value of 0.255
# Rounds 10000
# decay rate modified at 10000 with current value of 0.25
# decay rate modified at 10000 with current value of 0.25
# decay rate modified at 11000 with current value of 0.245
# decay rate modified at 11000 with current value of 0.245
# decay rate modified at 12000 with current value of 0.24
# decay rate modified at 12000 with current value of 0.24
# decay rate modified at 13000 with current value of 0.23500000000000001
# decay rate modified at 13000 with current value of 0.23500000000000001
# decay rate modified at 14000 with current value of 0.23
# decay rate modified at 14000 with current value of 0.23
# decay rate modified at 15000 with current value of 0.22499999999999998
# decay rate modified at 15000 with current value of 0.22499999999999998
# decay rate modified at 16000 with current value of 0.21999999999999997
# decay rate modified at 16000 with current value of 0.21999999999999997
# decay rate modified at 17000 with current value of 0.21499999999999997
# decay rate modified at 17000 with current value of 0.21499999999999997
# decay rate modified at 18000 with current value of 0.21
# decay rate modified at 18000 with current value of 0.21
# decay rate modified at 19000 with current value of 0.20500000000000002
# decay rate modified at 19000 with current value of 0.20500000000000002
# Rounds 20000
# decay rate modified at 20000 with current value of 0.2
# decay rate modified at 20000 with current value of 0.2
# decay rate modified at 21000 with current value of 0.195
# decay rate modified at 21000 with current value of 0.195
# decay rate modified at 22000 with current value of 0.19
# decay rate modified at 22000 with current value of 0.19
# decay rate modified at 23000 with current value of 0.185
# decay rate modified at 23000 with current value of 0.185
# decay rate modified at 24000 with current value of 0.18
# decay rate modified at 24000 with current value of 0.18
# decay rate modified at 25000 with current value of 0.175
# decay rate modified at 25000 with current value of 0.175
# decay rate modified at 26000 with current value of 0.16999999999999998
# decay rate modified at 26000 with current value of 0.16999999999999998
# decay rate modified at 27000 with current value of 0.16499999999999998
# decay rate modified at 27000 with current value of 0.16499999999999998
# decay rate modified at 28000 with current value of 0.15999999999999998
# decay rate modified at 28000 with current value of 0.15999999999999998
# decay rate modified at 29000 with current value of 0.155
# decay rate modified at 29000 with current value of 0.155
# Rounds 30000
# decay rate modified at 30000 with current value of 0.15
# decay rate modified at 30000 with current value of 0.15
# decay rate modified at 31000 with current value of 0.145
# decay rate modified at 31000 with current value of 0.145
# decay rate modified at 32000 with current value of 0.14
# decay rate modified at 32000 with current value of 0.14
# decay rate modified at 33000 with current value of 0.135
# decay rate modified at 33000 with current value of 0.135
# decay rate modified at 34000 with current value of 0.13
# decay rate modified at 34000 with current value of 0.13
# decay rate modified at 35000 with current value of 0.125
# decay rate modified at 35000 with current value of 0.125
# decay rate modified at 36000 with current value of 0.12
# decay rate modified at 36000 with current value of 0.12
# decay rate modified at 37000 with current value of 0.11499999999999999
# decay rate modified at 37000 with current value of 0.11499999999999999
# decay rate modified at 38000 with current value of 0.11
# decay rate modified at 38000 with current value of 0.11
# decay rate modified at 39000 with current value of 0.105
# decay rate modified at 39000 with current value of 0.105
# Rounds 40000
# decay rate modified at 40000 with current value of 0.09999999999999999
# decay rate modified at 40000 with current value of 0.09999999999999999
# decay rate modified at 41000 with current value of 0.09500000000000001
# decay rate modified at 41000 with current value of 0.09500000000000001
# decay rate modified at 42000 with current value of 0.09000000000000001
# decay rate modified at 42000 with current value of 0.09000000000000001
# decay rate modified at 43000 with current value of 0.085
# decay rate modified at 43000 with current value of 0.085
# decay rate modified at 44000 with current value of 0.08
# decay rate modified at 44000 with current value of 0.08
# decay rate modified at 45000 with current value of 0.075
# decay rate modified at 45000 with current value of 0.075
# decay rate modified at 46000 with current value of 0.06999999999999999
# decay rate modified at 46000 with current value of 0.06999999999999999
# decay rate modified at 47000 with current value of 0.06500000000000002
# decay rate modified at 47000 with current value of 0.06500000000000002
# decay rate modified at 48000 with current value of 0.06000000000000001
# decay rate modified at 48000 with current value of 0.06000000000000001
# decay rate modified at 49000 with current value of 0.05500000000000001
# decay rate modified at 49000 with current value of 0.05500000000000001

# %%
import random
class HumanPlayer:
    def __init__(self, name):
        self.name = name
    def chooseAction(self, positions):
        return random.choice(positions)
         
    def addState(self, state):
        pass

    def feedReward(self, reward):
        pass

    def reset(self):
        pass

# %%
# Test the learning
# Test Method 1: Play against computer player

# %%
   def testgame(p1,p2, ngames):
        p1_wins = 0
        p2_wins = 0
        ties = 0
    
        for _ in range(ngames):
            st = State(p1,p2) 
            winlist= st.play2()  # Human (p1) plays first against Computer (p2)
            if winlist==1:
                p1_wins+=1
            elif winlist==-1:
                p2_wins+=1
            else:
                ties+=1
        total_games = p1_wins + p2_wins + ties
        p1_win_prob = p1_wins / total_games
        p2_win_prob = p2_wins / total_games
        tie_prob = ties / total_games
    
        return p1_win_prob, p2_win_prob, tie_prob

# %%
# Test 1 - player trained with constant epsilon 
p1 = HumanPlayer("RandomPlayer")
p2 = Player("Computer", start_exp_rate=0)
p2.loadPolicy("policy_p2_cp1_cp2")

p1_win_prob, p2_win_prob, tie_prob = testgame(p1, p2, 1000)
print("Player 1 ({}): Winning Probability: {:.2%}".format(p1.name, p1_win_prob))
print("Player 2 ({}): Winning Probability: {:.2%}".format(p2.name, p2_win_prob))
print("Tie Probability: {:.2%}".format(tie_prob))
# Out:
# Player 1 (RandomPlayer): Winning Probability: 49.20%
# Player 2 (Computer): Winning Probability: 46.00%
# Tie Probability: 4.80%

# %%
# Test 2 - one player trained with decaying epsilon 
p1 = HumanPlayer("RandomPlayer")
p2 = Player("Computer", start_exp_rate=0)
p2.loadPolicy("policy_p2_dp1_cp2")

p1_win_prob, p2_win_prob, tie_prob = testgame(p1, p2, 1000)
p1_win_prob, p2_win_prob, tie_prob = testgame(p1, p2, 1000)
print("Player 1 ({}): Winning Probability: {:.2%}".format(p1.name, p1_win_prob))
print("Player 2 ({}): Winning Probability: {:.2%}".format(p2.name, p2_win_prob))
print("Tie Probability: {:.2%}".format(tie_prob))
# Out:
# Player 1 (RandomPlayer): Winning Probability: 49.50%
# Player 2 (Computer): Winning Probability: 46.40%
# Tie Probability: 4.10%

# %%
# Test 3 - both players trained with decaying epsilon 
p1 = HumanPlayer("RandomPlayer")
p2 = Player("Computer", start_exp_rate=0)
p2.loadPolicy("policy_p2_dp1_dp2")

p1_win_prob, p2_win_prob, tie_prob = testgame(p1, p2, 1000)
print("Player 1 ({}): Winning Probability: {:.2%}".format(p1.name, p1_win_prob))
print("Player 2 ({}): Winning Probability: {:.2%}".format(p2.name, p2_win_prob))
print("Tie Probability: {:.2%}".format(tie_prob))
# Out:
# Player 1 (RandomPlayer): Winning Probability: 52.30%
# Player 2 (Computer): Winning Probability: 44.10%
# Tie Probability: 3.60%
